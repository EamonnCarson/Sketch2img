# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import torch
from dataset import SketchyGanDataset

from torchvision import transforms

# %%
npzfile = np.load("dataset_stats.npz")
photos_mean = npzfile['photos_mean']
photos_std = npzfile['photos_std']
photos_scaling = npzfile['photos_scaling']
sketches_mean = npzfile['sketches_mean']
sketches_std = npzfile['sketches_std']
sketches_scaling = npzfile['sketches_scaling']

DATA_DIR = '../learning/datasets/sketchy/256x256'
PHOTOS_AUG = 'tx_000100000000'
PHOTOS_DIR = os.path.join(DATA_DIR, 'photo', PHOTOS_AUG)
SKETCHES_AUG = 'tx_000000000010'
SKETCHES_DIR = os.path.join(DATA_DIR, 'sketch', SKETCHES_AUG)
INFO_DIR = '../learning/datasets/info-06-04/info'

# %%
sketchygan_dataset = SketchyGanDataset(PHOTOS_DIR, SKETCHES_DIR, INFO_DIR)

# %%
original = sketchygan_dataset[0][0]
original
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8EE31B5BE0>

# %%
color_jitter = transforms.ColorJitter(brightness=0.3, contrast=0.2)(original)
color_jitter
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8EE322E668>

# %%
resized = transforms.Resize((64, 64))(color_jitter)
resized
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8EE346E470>

# %%
original_sketch = sketchygan_dataset[7][1]
original_sketch
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8EE3137EB8>

# %%
from dataset import InvertTransform
inverted = PIL.ImageOps.invert(original_sketch)
inverted
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8EE30D9208>

# %%
resized = transforms.Resize((64, 64))(inverted)
resized
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8EE30D9438>

# %%
sketchygan_dataset[6][1]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8EE30DD550>
